# %%
from plot_utils import plot_histories 


city = "village0"

files = [
    f"../result_storage/{city}/history_{city}_no_policy_{i}.csv" 
    for i in range(10)
]
plot_histories(*files, group_days=2)

# %%
files = [
    f"../result_storage/tmp/history_{city}_quarantine_{i}.csv" 
    for i in range(10)
]

plot_histories(*files, group_days=2)
