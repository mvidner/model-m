# %%
from plot_utils import plot_histories 

files = [
    f"../result_storage/tmp/history_seirsplus_no_policy_{i}.csv" 
    for i in range(10)
]
plot_histories(*files, group_days=2)

# %%
files = [
    f"../result_storage/tmp/history_seirsplus_quarantine_{i}.csv" 
    for i in range(10)
]

plot_histories(*files, group_days=2)
